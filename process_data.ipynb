# %%
import pandas as pd

# 读取数据
df = pd.read_csv('monsters.csv')

# 统计每个地点出现的妖怪数量，并获取妖怪名称
# 首先，我们按地点分组，并将妖怪名字合并为一个列表，计数每个地点的妖怪数量
grouped = df.groupby('所在地').agg(
    妖怪数量=('姓名', 'count'),         # 统计每个地点的妖怪数量
    妖怪名称=('姓名', lambda x: ', '.join(x))  # 合并妖怪名称为一个字符串，使用逗号分隔
).reset_index()

# 按妖怪数量降序排序
grouped = grouped.sort_values(by='妖怪数量', ascending=False)

# 将结果保存到新的 CSV 文件
grouped.to_csv('monsters_summary.csv', index=False, encoding='utf-8')

# 确认结果已保存
print("数据已保存到 monsters_summary.csv")
# Out:
# 数据已保存到 monsters_summary.csv

# %%
# merged_characters.py

journey_to_the_west_characters = {
    '佛家': [
        {'灵感大王': ['灵感大王', '乌龟精']},
        {'如意真仙': ['如意真仙']},
        {'黄眉老佛': ['黄眉老佛', '黄眉怪']},
        {'如来佛祖': ['如来', '释迦牟尼佛', '大觉金仙']},
        {'观音菩萨': ['观音', '南海观音', '南海大士', '慈航真人']},
        {'弥勒佛': ['弥勒佛', '笑和尚', '未来佛']},
        {'地藏王菩萨': ['地藏菩萨', '幽冥教主']},
        {'文殊菩萨': ['文殊师利', '文殊菩萨']},
        {'普贤菩萨': ['普贤菩萨']},
        {'灵吉菩萨': ['灵吉菩萨']},
        {'大势至菩萨': ['大势至菩萨']},
        {'燃灯古佛': ['燃灯佛', '燃灯道人']},
        {'韦驮天尊': ['韦驮菩萨']},
        {'十八罗汉': ['罗汉']},
        {'青狮精': ['青狮怪', '青毛狮子']},
        {'白象精': ['白象怪', '大白象']},
        {'金翅大鹏雕': ['大鹏', '金翅鸟', '鹏魔王']}
    ],
    '天庭': [
        {'寅将军': ['寅将军']},
        {'熊山君': ['熊山君']},
        {'特处士': ['特处士']},
        {'虎先锋': ['虎先锋']},
        {'劲节十八公': ['劲节十八公']},
        {'孤直公': ['孤直公']},
        {'凌空子': ['凌空子']},
        {'拂云叟': ['拂云叟']},
        {'杏仙': ['杏仙']},
        {'赤身鬼使': ['赤身鬼使']},
        {'赛太岁部下先锋': ['赛太岁部下先锋']},
        {'有来有去': ['有来有去']},
        {'赛太岁': ['赛太岁']},
        {'百眼魔君': ['百眼魔君']},
        {'云程万里鹏': ['云程万里鹏']},
        {'九灵元圣': ['九灵元圣']},
        {'辟寒大王': ['辟寒大王']},
        {'辟暑大王': ['辟暑大王']},
        {'辟尘大王': ['辟尘大王']},
        {'玉兔精': ['玉兔精']},
        {'玉皇大帝': ['玉皇', '天尊', '昊天上帝']},
        {'王母娘娘': ['王母', '西王母']},
        {'太白金星': ['太白星君', '金星']},
        {'哪吒': ['哪吒三太子', '三太子']},
        {'二郎神杨戬': ['二郎神', '杨戬', '昭惠真君']},
        {'托塔李天王': ['托塔天王', '李靖']},
        {'九天玄女': ['九天玄女']},
        {'南斗星君': ['南斗星官']},
        {'北斗星君': ['北斗星官']},
        {'太上老君': ['太上道祖', '老君', '道德天尊']},
        {'月宫嫦娥': ['嫦娥']},
        {'东海龙王敖广': ['敖广', '龙王']},
        {'南海龙王敖钦': ['敖钦']},
        {'西海龙王敖闰': ['敖闰']},
        {'北海龙王敖顺': ['敖顺']},
        {'雷公电母': ['雷公', '电母']},
        {'风婆': ['风婆']},
        {'五方揭谛': ['五方揭谛']},
        {'四值功曹': ['功曹']},
        {'三清': ['元始天尊', '灵宝天尊', '道德天尊']},
        {'青牛精': ['青牛', '青牛精']},
        {'奎木狼': ['奎木狼']},
        {'黄眉怪': ['黄眉童子', '黄眉怪']}
    ],
    '其他妖怪': [
        {'红孩儿': ['红孩儿', '圣婴大王']},
        {'白骨精': ['白骨精', '白骨夫人', '白骨怪']},
        {'黄袍怪': ['黄袍怪', '黄袍郎']},
        {'金角大王': ['金角大王', '金角']},
        {'银角大王': ['银角大王', '银角']},
        {'九头虫': ['九头虫', '九头怪']},
        {'牛魔王': ['牛魔王', '平天大圣']},
        {'铁扇公主': ['铁扇公主', '罗刹女']},
        {'蜘蛛精': ['蜘蛛精', '蜘蛛怪', '七蛛精']},
        {'蝎子精': ['蝎子精', '蝎精']},
        {'白面狐狸': ['狐狸精']},
        {'万圣公主': ['万圣公主']},
        {'黑水河老鼋': ['老鼋', '神龟']},
        {'黄风怪': ['黄风怪']},
        {'黑熊精': ['黑熊精', '熊罴怪', '黑熊怪']},
        {'赛太岁': ['赛太岁']},
        {'独角兕大王': ['独角兕大王', '独角大王']},
        {'狮驼王': ['狮驼王', '青毛狮子精']},
        {'蛟魔王': ['蛟魔王']},
        {'灵感大王': ['灵感大王', '乌龟精']},
        {'白鹿精': ['白鹿精', '白鹿', '白鹿怪']},
        {'猕猴王': ['猕猴王', '猕猴怪']},
        {'混世魔王': ['混世魔王', '混世大王']},
        {'通臂猿猴': ['通臂猿猴']},
        {'赤尻马猴': ['赤尻马猴']},
        {'狮狔王': ['狮狔王']},
        {'𤟹狨王': ['𤟹狨王']},
        {'独角鬼王': ['独角鬼王']},
        {'白衣秀士': ['白衣秀士', '白花蛇怪']},
        {'凌虚子': ['凌虚子', '苍狼怪']},
        {'精细鬼': ['精细鬼']},
        {'伶俐虫': ['伶俐虫']},
        {'巴山虎': ['巴山虎']},
        {'倚海龙': ['倚海龙']},
        {'九尾狐狸精': ['九尾狐狸精']},
        {'狐阿七大王': ['狐阿七大王']},
        {'青毛狮子怪': ['青毛狮子怪']},
        {'红孩儿': ['红孩儿', '圣婴大王']},
        {'鼍龙怪': ['鼍龙怪']},
        {'虎力大仙': ['虎力大仙']},
        {'鹿力大仙': ['鹿力大仙']},
        {'羊力大仙': ['羊力大仙']},
        {'斑衣鳜婆': ['斑衣鳜婆']},
        {'独角兕大王': ['独角兕大王', '独角大王']},
        {'蝎子精': ['蝎子精', '蝎精']},
        {'六耳猕猴': ['六耳猕猴']},
        {'玉面公主': ['玉面公主']},
        {'奔波儿灞': ['奔波儿灞']},
        {'灞波儿奔': ['灞波儿奔']},
        {'九头虫': ['九头虫', '九头怪']},
        {'蟒蛇精': ['蟒蛇精']},
        {'猩猩怪': ['猩猩怪']},
        {'蜜蜂精': ['蜜蜂精']},
        {'蚂蜂精': ['蚂蜂精']},
        {'蠦蜂精': ['蠦蜂精']},
        {'班毛精': ['班毛精']},
        {'牛蜢精': ['牛蜢精']},
        {'抹蜡精': ['抹蜡精']},
        {'蜻蜓精': ['蜻蜓精']},
        {'小钻风': ['小钻风']},
        {'青毛狮子怪': ['青毛狮子怪']},
        {'黄牙老象怪': ['黄牙老象怪']},
        {'白鹿怪': ['白鹿怪']},
        {'白面狐狸精': ['白面狐狸精']},
        {'金鼻白毛老鼠精': ['金鼻白毛老鼠精']},
        {'南山大王': ['南山大王']},
        {'铁背苍狼怪': ['铁背苍狼怪']},
        {'黄狮精': ['黄狮精']},
        {'刁钻古怪': ['刁钻古怪']},
        {'古怪刁钻': ['古怪刁钻']},
        {'青脸儿怪': ['青脸儿怪']},
        {'猱狮怪': ['猱狮怪']},
        {'雪狮怪': ['雪狮怪']},
        {'狻猊狮怪': ['狻猊狮怪']},
        {'抟象狮怪': ['抟象狮怪']},
        {'白泽狮怪': ['白泽狮怪']},
        {'伏狸狮怪': ['伏狸狮怪']}
    ]
}

# 示例：访问佛家类别中的所有角色及其别名
# for monster in merged_characters['佛家']:
#     for name, aliases in monster.items():
#         print(f"主名：{name}, 别名：{aliases}")


# 示例：访问佛家类别中的所有名字
# print(yaogua_classification['佛家'])



with open('xiyouji.txt', 'r', encoding='utf-8') as file:
    content = file.read()  # 读取整个文件内容
    # print(content)

contents = content.split('\n')  # 按行分割内容

print(len(contents))  # 输出内容的行数

chapters = ['第一回', '第二回', '第三回', '第四回', '第五回', '第六回', '第七回', '第八回', '第九回', '第十回', '第十一回', '第十二回', '第十三回', '第十四回', '第十五回', '第十六回', '第十七回', '第十八回', '第十九回', '第二十回', '第二十一回', '第二十二回', '第二十三回', '第二十四回', '第二十五回', '第二十六回', '第二十七回', '第二十八回', '第二十九回', '第三十回', '第三十一回', '第三十二回', '第三十三回', '第三十四回', '第三十五回', '第三十六回', '第三十七回', '第三十八回', '第三十九回', '第四十回', '第四十一回', '第四十二回', '第四十三回', '第四十四回', '第四十五回', '第四十六回', '第四十七回', '第四十八回', '第四十九回', '第五十回', '第五十一回', '第五十二回', '第五十三回', '第五十四回', '第五十五回', '第五十六回', '第五十七回', '第五十八回', '第五十九回', '第六十回', '第六十一回', '第六十二回', '第六十三回', '第六十四回', '第六十五回', '第六十六回', '第六十七回', '第六十八回', '第六十九回', '第七十回', '第七十一回', '第七十二回', '第七十三回', '第七十四回', '第七十五回', '第七十六回', '第七十七回', '第七十八回', '第七十九回', '第八十回', '第八十一回', '第八十二回', '第八十三回', '第八十四回', '第八十五回', '第八十六回', '第八十七回', '第八十八回', '第八十九回', '第九十回', '第九十一回', '第九十二回', '第九十三回', '第九十四回', '第九十五回', '第九十六回', '第九十七回', '第九十八回', '第九十九回', '第一百回']

chapters_index = {'第一回': '', '第二回': '', '第三回': '', '第四回': '', '第五回': '', '第六回': '', '第七回': '', '第八回': '', '第九回': '', '第十回': '', '第十一回': '', '第十二回': '', '第十三回': '', '第十四回': '', '第十五回': '', '第十六回': '', '第十七回': '', '第十八回': '', '第十九回': '', '第二十回': '', '第二十一回': '', '第二十二回': '', '第二十三回': '', '第二十四回': '', '第二十五回': '', '第二十六回': '', '第二十七回': '', '第二十八回': '', '第二十九回': '', '第三十回': '', '第三十一回': '', '第三十二回': '', '第三十三回': '', '第三十四回': '', '第三十五回': '', '第三十六回': '', '第三十七回': '', '第三十八回': '', '第三十九回': '', '第四十回': '', '第四十一回': '', '第四十二回': '', '第四十三回': '', '第四十四回': '', '第四十五回': '', '第四十六回': '', '第四十七回': '', '第四十八回': '', '第四十九回': '', '第五十回': '', '第五十一回': '', '第五十二回': '', '第五十三回': '', '第五十四回': '', '第五十五回': '', '第五十六回': '', '第五十七回': '', '第五十八回': '', '第五十九回': '', '第六十回': '', '第六十一回': '', '第六十二回': '', '第六十三回': '', '第六十四回': '', '第六十五回': '', '第六十六回': '', '第六十七回': '', '第六十八回': '', '第六十九回': '', '第七十回': '', '第七十一回': '', '第七十二回': '', '第七十三回': '', '第七十四回': '', '第七十五回': '', '第七十六回': '', '第七十七回': '', '第七十八回': '', '第七十九回': '', '第八十回': '', '第八十一回': '', '第八十二回': '', '第八十三回': '', '第八十四回': '', '第八十五回': '', '第八十六回': '', '第八十七回': '', '第八十八回': '', '第八十九回': '', '第九十回': '', '第九十一回': '', '第九十二回': '', '第九十三回': '', '第九十四回': '', '第九十五回': '', '第九十六回': '', '第九十七回': '', '第九十八回': '', '第九十九回': '', '第一百回': ''}

start = 0
end = 0

for j in range(len(chapters)):
    chapter = chapters[j]
    if chapter == '第一百回':
        chapters_index[chapter] = contents[start:]
        end = len(contents)

    else:
        for i in range(start, len(contents)):
            if chapter in contents[i]:
                start = i
                break

        for i in range(start, len(contents)):
            if i + 1 < len(contents) and chapters[j + 1] in contents[i + 1]:
                end = i
                break

        chapters_index[chapter] = contents[start:end]

    print("chapter: ", chapter)
    print("start: ", start)
    print("end: ", end)
    print('---------------------')
    
    start = end
# Out:
# 6905
# chapter:  第一回
# start:  2
# end:  127
# ---------------------
# chapter:  第二回
# start:  128
# end:  219
# ---------------------
# chapter:  第三回
# start:  220
# end:  271
# ---------------------
# chapter:  第四回
# start:  272
# end:  335
# ---------------------
# chapter:  第五回
# start:  336
# end:  403
# ---------------------
# chapter:  第六回
# start:  404
# end:  489
# ---------------------
# chapter:  第七回
# start:  490
# end:  607
# ---------------------
# chapter:  第八回
# start:  608
# end:  789
# ---------------------
# chapter:  第九回
# start:  790
# end:  851
# ---------------------
# chapter:  第十回
# start:  852
# end:  923
# ---------------------
# chapter:  第十一回
# start:  924
# end:  989
# ---------------------
# chapter:  第十二回
# start:  990
# end:  1049
# ---------------------
# chapter:  第十三回
# start:  1050
# end:  1099
# ---------------------
# chapter:  第十四回
# start:  1100
# end:  1183
# ---------------------
# chapter:  第十五回
# start:  1184
# end:  1255
# ...

# %%
import json

occur_times_list = {}

for chapter, content in chapters_index.items():
    print(chapter)
    occur_times = {'佛家': 0, '天庭': 0, '其他妖怪': 0}

    for i in range(len(content)):
        for place, monsters in journey_to_the_west_characters.items():
            for monster in monsters:
                for name, aliases in monster.items():
                    for alias in aliases:
                        # 统计 alias 在 countent[i] 中出现的次数 
                        occur_times[place] += content[i].count(alias)
                        break
        
    # normalize
    # total = sum(occur_times.values())
    # for place in occur_times:
    #     occur_times[place] /= (total + 1e-5)
    occur_times_list[chapter] = occur_times
    print(occur_times)
    print('---------------------')

with open('occur_times.json', 'w', encoding='utf-8') as file:
    json.dump(occur_times_list, file, ensure_ascii=False, indent=4)
# Out:
# 第一回
# {'佛家': 0, '天庭': 1, '其他妖怪': 0}
# ---------------------
# 第二回
# {'佛家': 0, '天庭': 0, '其他妖怪': 1}
# ---------------------
# 第三回
# {'佛家': 0, '天庭': 20, '其他妖怪': 7}
# ---------------------
# 第四回
# {'佛家': 0, '天庭': 7, '其他妖怪': 4}
# ---------------------
# 第五回
# {'佛家': 2, '天庭': 20, '其他妖怪': 4}
# ---------------------
# 第六回
# {'佛家': 9, '天庭': 10, '其他妖怪': 0}
# ---------------------
# 第七回
# {'佛家': 30, '天庭': 7, '其他妖怪': 0}
# ---------------------
# 第八回
# {'佛家': 28, '天庭': 3, '其他妖怪': 0}
# ---------------------
# 第九回
# {'佛家': 0, '天庭': 1, '其他妖怪': 2}
# ---------------------
# 第十回
# {'佛家': 1, '天庭': 0, '其他妖怪': 0}
# ---------------------
# 第十一回
# {'佛家': 1, '天庭': 0, '其他妖怪': 0}
# ---------------------
# 第十二回
# {'佛家': 9, '天庭': 0, '其他妖怪': 0}
# ---------------------
# 第十三回
# {'佛家': 1, '天庭': 11, '其他妖怪': 0}
# ---------------------
# 第十四回
# {'佛家': 4, '天庭': 1, '其他妖怪': 0}
# ---------------------
# 第十五回
# {'佛家': 4, '天庭': 10, '其他妖怪': 0}
# ---------------------
# 第十六回
# {'佛家': 7, '天庭': 3, '其他妖怪': 0}
# ...

# %%
import matplotlib.pyplot as plt

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False

# 创建画布
plt.figure(figsize=(10, 6))

# 绘制柱状图，将三个柱状图（佛家，天庭，其他妖怪）从下往上叠加，不要覆盖，使用bottom参数来实现这一点
for i, (place, color) in enumerate(zip(['佛家', '天庭', '其他妖怪'], ['r', 'g', 'b'])):
    heights = [occur_times_list[chapter][place] for chapter in chapters]
    plt.bar(chapters, heights, label=place, color=color, bottom=[sum(heights[:j]) for j in range(len(heights))])

# 添加标题
plt.title('各回中妖怪出现次数')

# 添加图例
plt.legend()

# 存储图片
plt.savefig('妖怪出现次数.png')
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimSun
# ...

# %%
# 找到'佛家'出现次数最多的章节，并且具体找出是哪个人物出现最多

max_occurs = 0
chapter = ''

for k, v in occur_times_list.items():
    if v['佛家'] > max_occurs:
        max_occurs = v['佛家']
        chapter = k

print('佛家出现次数最多的章节是：', chapter)

# 在这个章节里，找到佛家出现次数最多的妖怪
max_monster = ''
max_count = 0

for place, monsters in journey_to_the_west_characters.items():
    if place == '佛家':
        for monster in monsters:
            for name, aliases in monster.items():
                for alias in aliases:
                    count = 0
                    for line in chapters_index[chapter]:
                        count += line.count(alias)
                    if count > max_count:
                        max_count = count
                        max_monster = name

print('在这个章节里，佛家出现次数最多的妖怪是：', max_monster)
print('出现次数：', max_count)
# Out:
# 佛家出现次数最多的章节是： 第七十七回
# 在这个章节里，佛家出现次数最多的妖怪是： 如来佛祖
# 出现次数： 33

# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import json

# 您提供的归一化数据字典
with open('occur_times_norm.json', 'r', encoding='utf-8') as file:
    chapter_data = json.load(file)

# 定义中文数字到阿拉伯数字的映射
num_map = {
    '零': 0, '一': 1, '二': 2, '三': 3, '四':4, '五':5, '六':6, '七':7, '八':8, '九':9,
    '十':10, '百':100
}

def chapter_number(chapter):
    """
    将章节名称转换为数字，以便正确排序。
    例如：“第一回” -> 1，“第二十回” -> 20
    """
    match = re.match(r'第([一二三四五六七八九十百]+)回', chapter)
    if not match:
        return 0
    num_str = match.group(1)
    total = 0
    unit = 1
    for char in reversed(num_str):
        if char == '十':
            if total == 0:
                total += 10
            else:
                total += 10 * unit
            unit = 1
        elif char == '百':
            total += 100 * unit
            unit =1
        else:
            total += num_map.get(char,0) * unit
            unit *=10
    return total

# 获取并排序回合名称
sorted_chapters = sorted(chapter_data.keys(), key=lambda x: chapter_number(x))

# 提取每个类别的数据
buddhism = [chapter_data[chapter]['佛家'] for chapter in sorted_chapters]
heavenly_court = [chapter_data[chapter]['天庭'] for chapter in sorted_chapters]
other_monsters = [chapter_data[chapter]['其他妖怪'] for chapter in sorted_chapters]

# 设置柱状图的位置
x = np.arange(len(sorted_chapters))  # 回合数量
width = 0.8  # 柱子的宽度

# 创建图形和轴
fig, ax = plt.subplots(figsize=(30, 15))  # 调整图表尺寸以适应100回

# 绘制堆叠柱状图
ax.bar(x, buddhism, width, label='佛家', color='gold')
ax.bar(x, heavenly_court, width, bottom=buddhism, label='天庭', color='skyblue')
bottom_total = np.array(buddhism) + np.array(heavenly_court)
ax.bar(x, other_monsters, width, bottom=bottom_total, label='其他妖怪', color='lightgreen')

# 设置标签和标题
ax.set_xlabel('回合', fontsize=20)
ax.set_ylabel('比例', fontsize=20)
ax.set_title('100回中各类别妖怪比例堆叠柱状图', fontsize=24)

# 设置x轴刻度
ax.set_xticks(x)
# 由于回合较多，建议只显示每隔10回的标签
tick_interval = 10
ax.set_xticklabels([chapter if (i % tick_interval == 0) else '' for i, chapter in enumerate(sorted_chapters)],
                   rotation=90, fontsize=10)

# 添加图例
ax.legend(fontsize=16)

# 优化布局
plt.tight_layout()

# 存储图形（名称为柱状图的英文.png）
plt.savefig('stacked_bar_chart.png')
# Out:
# /tmp/ipykernel_588747/1018325567.py:79: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_588747/1018325567.py:79: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_588747/1018325567.py:79: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_588747/1018325567.py:79: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_588747/1018325567.py:79: UserWarning: Glyph 21313 (\N{CJK UNIFIED IDEOGRAPH-5341}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_588747/1018325567.py:79: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from current font.
#   plt.tight_layout()
# ...
